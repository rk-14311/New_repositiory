# %% [markdown]
# <a href="https://colab.research.google.com/github/rk-14311/New_repositiory/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
file_path='/content/drive/MyDrive/Cleaned_EVEN.xlsx'
df=pd.read_excel(file_path)

# %%
df.describe()
# Out:
#                         booking_date  number_of_travelers    total_cost  \
# count                           5200          5200.000000   4937.000000
# mean   2023-08-21 12:47:21.230769152             3.254808  52386.533753
# min              2022-08-20 00:00:00             1.000000   5010.980000
# 25%              2023-02-20 18:00:00             2.000000  27931.950000
# 50%              2023-08-23 00:00:00             2.000000  53023.540000
# 75%              2024-02-21 00:00:00             3.000000  76636.490000
# max              2024-08-19 00:00:00            10.000000  99979.710000
# std                              NaN             2.491585  27720.304328
#
#                           start_date                       end_date  \
# count                           5200                           5200
# mean   2024-02-18 19:28:53.538461440  2025-02-16 19:05:37.846153984
# min              2023-08-20 00:00:00            2024-08-20 00:00:00
# ...

# %%
df['luxury'] = 53732.46515771526

# %%
df['premium']= 51603.118567980695

# %%
df['standard']=52146.55261007536

# %%
df.describe()
# Out:
#                         booking_date  number_of_travelers    total_cost  \
# count                           5200          5200.000000   4937.000000
# mean   2023-08-21 12:47:21.230769152             3.254808  52386.533753
# min              2022-08-20 00:00:00             1.000000   5010.980000
# 25%              2023-02-20 18:00:00             2.000000  27931.950000
# 50%              2023-08-23 00:00:00             2.000000  53023.540000
# 75%              2024-02-21 00:00:00             3.000000  76636.490000
# max              2024-08-19 00:00:00            10.000000  99979.710000
# std                              NaN             2.491585  27720.304328
#
#                           start_date                       end_date  \
# count                           5200                           5200
# mean   2024-02-18 19:28:53.538461440  2025-02-16 19:05:37.846153984
# min              2023-08-20 00:00:00            2024-08-20 00:00:00
# ...

# %%
df['Unique Destinations Count']=858
